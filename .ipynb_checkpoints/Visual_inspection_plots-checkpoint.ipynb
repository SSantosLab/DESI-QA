# %%
import matplotlib.pyplot as plt
import numpy as np 
from astropy.io import fits
plt.rcParams.update({"figure.dpi":130})

# %%
im1 = fits.getdata('/home/msdos/um_scripts/sbigpics/tests/20230120-123841.fits')
im2 = fits.getdata('/home/msdos/um_scripts/sbigpics/tests/20230120-124107.fits')
im3 = fits.getdata('/home/msdos/um_scripts/sbigpics/tests/20230120-124456.fits')
im4 = fits.getdata('/home/msdos/um_scripts/sbigpics/tests/20230120-124732.fits')

imlist=[]
for iname in ['/home/msdos/um_scripts/sbigpics/tests/20230120-130315.fits', 
              '/home/msdos/um_scripts/sbigpics/tests/20230120-130322.fits', 
              '/home/msdos/um_scripts/sbigpics/tests/20230120-130330.fits', 
              '/home/msdos/um_scripts/sbigpics/tests/20230120-130339.fits']:
    imlist.append(fits.getdata(iname))

# %%
for im in [im1, im2, im3, im4]:
    plt.imshow(np.fliplr(im), origin='lower'); plt.show()
