# %%
from astropy.io import fits 
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams.update({"figure.dpi":130})

# %%
fns = !ls sbigpics/20230119-190518
ff = [fits.getdata(f"sbigpics/20230119-190518/{i}") for i in fns]
fns
# Out:
# ['20230119-190520.fits', '20230119-190528.fits']

# %%
# !ls sbigpics/20230119-165706/
# Out:
# ls: cannot access 'sbigpics/20230119-165706/': No such file or directory

# %%
imdiff = ff[0]
for i in ff[1:]:
    imdiff -= i
plt.imshow(imdiff); plt.show()

# %%
im
# Out:
# 0
