# %%
import matplotlib.pyplot as plt
import numpy as np 
from astropy.io import fits
plt.rcParams.update({"figure.dpi":130})

# %%
plt.title("Expected home position in 2023-01-20")
plt.imshow(np.fliplr(fits.getdata("sbigpics/Homepos_20230120-133352.fits")), origin='lower'); plt.show()

# %%
imlist=[]
for iname in ['/home/msdos/um_scripts/sbigpics/tests/20230120-130719.fits', 
              '/home/msdos/um_scripts/sbigpics/tests/20230120-130727.fits', 
              '/home/msdos/um_scripts/sbigpics/tests/20230120-130734.fits', 
              '/home/msdos/um_scripts/sbigpics/tests/20230120-130742.fits', 
             '/home/msdos/um_scripts/sbigpics/tests/20230120-130751.fits',
             '/home/msdos/um_scripts/sbigpics/tests/20230120-130758.fits']:
    imlist.append(fits.getdata(iname))

# %%
for im in imlist:
    plt.imshow(np.fliplr(im), origin='lower'); plt.show()
